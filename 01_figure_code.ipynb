# %% [markdown]
# # **Import pyXLMS**

# %%
import pyXLMS

print(f"Using pyXLMS version {pyXLMS.__version__}")
# Out:
# Using pyXLMS version 1.7.3

# %% [markdown]
# # **Load pLink Results**

# %% [markdown]
# ## **Replicate 1**
#
# *****

# %%
plink_r1 = pyXLMS.parser.read(
    [
        "results/plink/Cas9_HeLa_Cyt_r1/reports/result_2025.11.05.filtered_cross-linked_spectra.csv",
        "results/plink/Cas9_HeLa_Cyt_r1/reports/result_2025.11.05.filtered_cross-linked_peptides.csv",
    ],
    engine="pLink",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading pLink crosslinks...: 100%|██████████████████████████████████████████████████████████████████████████████| 592/592 [00:00<00:00, 30122.14it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(plink_r1);
# Out:
# Number of CSMs: 772.0
# Number of unique CSMs: 768.0
# Number of intra CSMs: 703.0
# Number of inter CSMs: 69.0
# Number of target-target CSMs: 772.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.591583
# Maximum CSM score: 0.999926
# Number of crosslinks: 592.0
# Number of unique crosslinks by peptide: 585.0
# Number of unique crosslinks by protein: 442.0
# Number of intra crosslinks: 534.0
# Number of inter crosslinks: 58.0
# Number of target-target crosslinks: 592.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
plink_r1 = pyXLMS.transform.reannotate_positions(
    plink_r1,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 592/592 [00:13<00:00, 43.84it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
plink_r1 = pyXLMS.transform.unique(plink_r1, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(plink_r1);
# Out:
# Number of CSMs: 768.0
# Number of unique CSMs: 768.0
# Number of intra CSMs: 699.0
# Number of inter CSMs: 69.0
# Number of target-target CSMs: 768.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.591583
# Maximum CSM score: 0.999926
# Number of crosslinks: 443.0
# Number of unique crosslinks by peptide: 443.0
# Number of unique crosslinks by protein: 443.0
# Number of intra crosslinks: 388.0
# Number of inter crosslinks: 55.0
# Number of target-target crosslinks: 443.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# ## **Replicate 2**
#
# *****

# %%
plink_r2 = pyXLMS.parser.read(
    [
        "results/plink/Cas9_HeLa_Cyt_r2/reports/result_2025.11.05.filtered_cross-linked_spectra.csv",
        "results/plink/Cas9_HeLa_Cyt_r2/reports/result_2025.11.05.filtered_cross-linked_peptides.csv",
    ],
    engine="pLink",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading pLink crosslinks...: 100%|██████████████████████████████████████████████████████████████████████████████| 578/578 [00:00<00:00, 25940.63it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(plink_r2);
# Out:
# Number of CSMs: 768.0
# Number of unique CSMs: 765.0
# Number of intra CSMs: 682.0
# Number of inter CSMs: 86.0
# Number of target-target CSMs: 768.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 9.9e-05
# Maximum CSM score: 0.999965
# Number of crosslinks: 578.0
# Number of unique crosslinks by peptide: 571.0
# Number of unique crosslinks by protein: 433.0
# Number of intra crosslinks: 507.0
# Number of inter crosslinks: 71.0
# Number of target-target crosslinks: 578.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
plink_r2 = pyXLMS.transform.reannotate_positions(
    plink_r2,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 578/578 [00:13<00:00, 44.08it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
plink_r2 = pyXLMS.transform.unique(plink_r2, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(plink_r2);
# Out:
# Number of CSMs: 765.0
# Number of unique CSMs: 765.0
# Number of intra CSMs: 680.0
# Number of inter CSMs: 85.0
# Number of target-target CSMs: 765.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 9.9e-05
# Maximum CSM score: 0.999965
# Number of crosslinks: 433.0
# Number of unique crosslinks by peptide: 433.0
# Number of unique crosslinks by protein: 433.0
# Number of intra crosslinks: 368.0
# Number of inter crosslinks: 65.0
# Number of target-target crosslinks: 433.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# ## **Replicate 3**
#
# *****

# %%
plink_r3 = pyXLMS.parser.read(
    [
        "results/plink/Cas9_HeLa_Cyt_r3/reports/result_2025.11.05.filtered_cross-linked_spectra.csv",
        "results/plink/Cas9_HeLa_Cyt_r3/reports/result_2025.11.05.filtered_cross-linked_peptides.csv",
    ],
    engine="pLink",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading pLink crosslinks...: 100%|███████████████████████████████████████████████████████████████████████████████| 562/562 [00:00<00:00, 9772.35it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(plink_r3);
# Out:
# Number of CSMs: 767.0
# Number of unique CSMs: 762.0
# Number of intra CSMs: 749.0
# Number of inter CSMs: 18.0
# Number of target-target CSMs: 767.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 8e-06
# Maximum CSM score: 0.999975
# Number of crosslinks: 562.0
# Number of unique crosslinks by peptide: 553.0
# Number of unique crosslinks by protein: 409.0
# Number of intra crosslinks: 552.0
# Number of inter crosslinks: 10.0
# Number of target-target crosslinks: 562.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
plink_r3 = pyXLMS.transform.reannotate_positions(
    plink_r3,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 562/562 [00:12<00:00, 43.85it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
plink_r3 = pyXLMS.transform.unique(plink_r3, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(plink_r3);
# Out:
# Number of CSMs: 762.0
# Number of unique CSMs: 762.0
# Number of intra CSMs: 744.0
# Number of inter CSMs: 18.0
# Number of target-target CSMs: 762.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 8e-06
# Maximum CSM score: 0.999975
# Number of crosslinks: 409.0
# Number of unique crosslinks by peptide: 409.0
# Number of unique crosslinks by protein: 409.0
# Number of intra crosslinks: 399.0
# Number of inter crosslinks: 10.0
# Number of target-target crosslinks: 409.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: nan
# Maximum crosslink score: nan

# %% [markdown]
# # **Load Scout Results**

# %% [markdown]
# ## **Replicate 1**
#
# *****

# %%
scout_r1 = pyXLMS.parser.read(
    [
        "results/scout/Cas9_HeLa_Cyt_r1/Cas9_HeLa_Cyt_r1_filtered_CSMs.csv",
        "results/scout/Cas9_HeLa_Cyt_r1/Cas9_HeLa_Cyt_r1_filtered_XLs.csv",
    ],
    engine="Scout",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading Scout crosslinks...: 100%|██████████████████████████████████████████████████████████████████████████████| 213/213 [00:00<00:00, 21353.99it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(scout_r1);
# Out:
# Number of CSMs: 271.0
# Number of unique CSMs: 271.0
# Number of intra CSMs: 261.0
# Number of inter CSMs: 10.0
# Number of target-target CSMs: 271.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.0035731601214006
# Maximum CSM score: 14.062453896120644
# Number of crosslinks: 213.0
# Number of unique crosslinks by peptide: 213.0
# Number of unique crosslinks by protein: 213.0
# Number of intra crosslinks: 205.0
# Number of inter crosslinks: 8.0
# Number of target-target crosslinks: 213.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 0.0203695575361681
# Maximum crosslink score: 16.819518356582872

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
scout_r1 = pyXLMS.transform.reannotate_positions(
    scout_r1,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 213/213 [00:04<00:00, 43.23it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
scout_r1 = pyXLMS.transform.unique(scout_r1, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(scout_r1);
# Out:
# Number of CSMs: 271.0
# Number of unique CSMs: 271.0
# Number of intra CSMs: 261.0
# Number of inter CSMs: 10.0
# Number of target-target CSMs: 271.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.0035731601214006
# Maximum CSM score: 14.062453896120644
# Number of crosslinks: 213.0
# Number of unique crosslinks by peptide: 213.0
# Number of unique crosslinks by protein: 213.0
# Number of intra crosslinks: 205.0
# Number of inter crosslinks: 8.0
# Number of target-target crosslinks: 213.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 0.0203695575361681
# Maximum crosslink score: 16.819518356582872

# %% [markdown]
# ## **Replicate 2**
#
# *****

# %%
scout_r2 = pyXLMS.parser.read(
    [
        "results/scout/Cas9_HeLa_Cyt_r2/Cas9_HeLa_Cyt_r2_filtered_CSMs.csv",
        "results/scout/Cas9_HeLa_Cyt_r2/Cas9_HeLa_Cyt_r2_filtered_XLs.csv",
    ],
    engine="Scout",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading Scout crosslinks...: 100%|██████████████████████████████████████████████████████████████████████████████| 234/234 [00:00<00:00, 23396.68it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(scout_r2);
# Out:
# Number of CSMs: 318.0
# Number of unique CSMs: 318.0
# Number of intra CSMs: 301.0
# Number of inter CSMs: 17.0
# Number of target-target CSMs: 318.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.0027379282841667
# Maximum CSM score: 16.00687438748489
# Number of crosslinks: 234.0
# Number of unique crosslinks by peptide: 234.0
# Number of unique crosslinks by protein: 234.0
# Number of intra crosslinks: 219.0
# Number of inter crosslinks: 15.0
# Number of target-target crosslinks: 234.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 0.0212829947347597
# Maximum crosslink score: 17.53252983443032

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
scout_r2 = pyXLMS.transform.reannotate_positions(
    scout_r2,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 234/234 [00:05<00:00, 43.28it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
scout_r2 = pyXLMS.transform.unique(scout_r2, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(scout_r2);
# Out:
# Number of CSMs: 318.0
# Number of unique CSMs: 318.0
# Number of intra CSMs: 301.0
# Number of inter CSMs: 17.0
# Number of target-target CSMs: 318.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.0027379282841667
# Maximum CSM score: 16.00687438748489
# Number of crosslinks: 234.0
# Number of unique crosslinks by peptide: 234.0
# Number of unique crosslinks by protein: 234.0
# Number of intra crosslinks: 219.0
# Number of inter crosslinks: 15.0
# Number of target-target crosslinks: 234.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 0.0212829947347597
# Maximum crosslink score: 17.53252983443032

# %% [markdown]
# ## **Replicate 3**
#
# *****

# %%
scout_r3 = pyXLMS.parser.read(
    [
        "results/scout/Cas9_HeLa_Cyt_r3/Cas9_HeLa_Cyt_r3_filtered_CSMs.csv",
        "results/scout/Cas9_HeLa_Cyt_r3/Cas9_HeLa_Cyt_r3_filtered_XLs.csv",
    ],
    engine="Scout",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading Scout crosslinks...: 100%|██████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 20489.50it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(scout_r3);
# Out:
# Number of CSMs: 267.0
# Number of unique CSMs: 267.0
# Number of intra CSMs: 255.0
# Number of inter CSMs: 12.0
# Number of target-target CSMs: 267.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.0442565168089177
# Maximum CSM score: 17.776609023120013
# Number of crosslinks: 200.0
# Number of unique crosslinks by peptide: 200.0
# Number of unique crosslinks by protein: 200.0
# Number of intra crosslinks: 188.0
# Number of inter crosslinks: 12.0
# Number of target-target crosslinks: 200.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 0.0442565168089177
# Maximum crosslink score: 17.776609023120013

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
scout_r3 = pyXLMS.transform.reannotate_positions(
    scout_r3,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:04<00:00, 43.25it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
scout_r3 = pyXLMS.transform.unique(scout_r3, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(scout_r3);
# Out:
# Number of CSMs: 267.0
# Number of unique CSMs: 267.0
# Number of intra CSMs: 255.0
# Number of inter CSMs: 12.0
# Number of target-target CSMs: 267.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 0.0442565168089177
# Maximum CSM score: 17.776609023120013
# Number of crosslinks: 200.0
# Number of unique crosslinks by peptide: 200.0
# Number of unique crosslinks by protein: 200.0
# Number of intra crosslinks: 188.0
# Number of inter crosslinks: 12.0
# Number of target-target crosslinks: 200.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 0.0442565168089177
# Maximum crosslink score: 17.776609023120013

# %% [markdown]
# # **Load XlinkX Results**

# %% [markdown]
# ## **Replicate 1**
#
# *****

# %%
xlinkx_r1 = pyXLMS.parser.read(
    [
        "results/xlinkx/Cas9_HeLa_Cyt_r1/Cas9_HeLa_Cyt_r1_CSMs.xlsx",
        "results/xlinkx/Cas9_HeLa_Cyt_r1/Cas9_HeLa_Cyt_r1_XLs.xlsx",
    ],
    engine="XlinkX",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading XlinkX crosslinks...: 100%|█████████████████████████████████████████████████████████████████████████████| 157/157 [00:00<00:00, 17513.92it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(xlinkx_r1);
# Out:
# Number of CSMs: 181.0
# Number of unique CSMs: 181.0
# Number of intra CSMs: 152.0
# Number of inter CSMs: 29.0
# Number of target-target CSMs: 0.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 36.56
# Maximum CSM score: 191.91
# Number of crosslinks: 157.0
# Number of unique crosslinks by peptide: 157.0
# Number of unique crosslinks by protein: 157.0
# Number of intra crosslinks: 129.0
# Number of inter crosslinks: 28.0
# Number of target-target crosslinks: 157.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 36.69
# Maximum crosslink score: 191.91

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
xlinkx_r1 = pyXLMS.transform.reannotate_positions(
    xlinkx_r1,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 157/157 [00:03<00:00, 43.41it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
xlinkx_r1 = pyXLMS.transform.unique(xlinkx_r1, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(xlinkx_r1);
# Out:
# Number of CSMs: 181.0
# Number of unique CSMs: 181.0
# Number of intra CSMs: 152.0
# Number of inter CSMs: 29.0
# Number of target-target CSMs: 0.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 36.56
# Maximum CSM score: 191.91
# Number of crosslinks: 157.0
# Number of unique crosslinks by peptide: 157.0
# Number of unique crosslinks by protein: 157.0
# Number of intra crosslinks: 129.0
# Number of inter crosslinks: 28.0
# Number of target-target crosslinks: 157.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 36.69
# Maximum crosslink score: 191.91

# %% [markdown]
# ## **Replicate 2**
#
# *****

# %%
xlinkx_r2 = pyXLMS.parser.read(
    [
        "results/xlinkx/Cas9_HeLa_Cyt_r2/Cas9_HeLa_Cyt_r2_CSMs.xlsx",
        "results/xlinkx/Cas9_HeLa_Cyt_r2/Cas9_HeLa_Cyt_r2_XLs.xlsx",
    ],
    engine="XlinkX",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading XlinkX crosslinks...: 100%|█████████████████████████████████████████████████████████████████████████████| 170/170 [00:00<00:00, 18591.77it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(xlinkx_r2);
# Out:
# Number of CSMs: 205.0
# Number of unique CSMs: 205.0
# Number of intra CSMs: 174.0
# Number of inter CSMs: 31.0
# Number of target-target CSMs: 0.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 32.61
# Maximum CSM score: 240.79
# Number of crosslinks: 170.0
# Number of unique crosslinks by peptide: 170.0
# Number of unique crosslinks by protein: 170.0
# Number of intra crosslinks: 143.0
# Number of inter crosslinks: 27.0
# Number of target-target crosslinks: 170.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 33.19
# Maximum crosslink score: 240.79

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
xlinkx_r2 = pyXLMS.transform.reannotate_positions(
    xlinkx_r2,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 170/170 [00:03<00:00, 43.75it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
xlinkx_r2 = pyXLMS.transform.unique(xlinkx_r2, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(xlinkx_r2);
# Out:
# Number of CSMs: 205.0
# Number of unique CSMs: 205.0
# Number of intra CSMs: 174.0
# Number of inter CSMs: 31.0
# Number of target-target CSMs: 0.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 32.61
# Maximum CSM score: 240.79
# Number of crosslinks: 170.0
# Number of unique crosslinks by peptide: 170.0
# Number of unique crosslinks by protein: 170.0
# Number of intra crosslinks: 143.0
# Number of inter crosslinks: 27.0
# Number of target-target crosslinks: 170.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 33.19
# Maximum crosslink score: 240.79

# %% [markdown]
# ## **Replicate 3**
#
# *****

# %%
xlinkx_r3 = pyXLMS.parser.read(
    [
        "results/xlinkx/Cas9_HeLa_Cyt_r3/Cas9_HeLa_Cyt_r3_CSMs.xlsx",
        "results/xlinkx/Cas9_HeLa_Cyt_r3/Cas9_HeLa_Cyt_r3_XLs.xlsx",
    ],
    engine="XlinkX",
    crosslinker="DSBSO",
)
# Out:
# ...
# Reading XlinkX crosslinks...: 100%|█████████████████████████████████████████████████████████████████████████████| 111/111 [00:00<00:00, 17062.51it/s]

# %% [markdown]
# ### **Summary of the loaded results**

# %%
pyXLMS.transform.summary(xlinkx_r3);
# Out:
# Number of CSMs: 129.0
# Number of unique CSMs: 129.0
# Number of intra CSMs: 111.0
# Number of inter CSMs: 18.0
# Number of target-target CSMs: 0.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 49.37
# Maximum CSM score: 231.06
# Number of crosslinks: 111.0
# Number of unique crosslinks by peptide: 111.0
# Number of unique crosslinks by protein: 111.0
# Number of intra crosslinks: 94.0
# Number of inter crosslinks: 17.0
# Number of target-target crosslinks: 111.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 49.37
# Maximum crosslink score: 231.06

# %% [markdown]
# ### **Re-annotate positions for consistency between all search engine results**

# %%
xlinkx_r3 = pyXLMS.transform.reannotate_positions(
    xlinkx_r3,
    fasta="fasta/cas9_uniprotkb_proteome_UP000005640_AND_revi_2025_11_03.fasta",
)
# Out:
# ...
# Annotating crosslinks...: 100%|████████████████████████████████████████████████████████████████████████████████████| 111/111 [00:02<00:00, 43.86it/s]

# %% [markdown]
# ### **Only keep unique crosslink-spectrum-matches and crosslinks**

# %%
xlinkx_r3 = pyXLMS.transform.unique(xlinkx_r3, by="protein")

# %% [markdown]
# ### **Summary of transformed results**

# %%
pyXLMS.transform.summary(xlinkx_r3);
# Out:
# Number of CSMs: 129.0
# Number of unique CSMs: 129.0
# Number of intra CSMs: 111.0
# Number of inter CSMs: 18.0
# Number of target-target CSMs: 0.0
# Number of target-decoy CSMs: 0.0
# Number of decoy-decoy CSMs: 0.0
# Minimum CSM score: 49.37
# Maximum CSM score: 231.06
# Number of crosslinks: 111.0
# Number of unique crosslinks by peptide: 111.0
# Number of unique crosslinks by protein: 111.0
# Number of intra crosslinks: 94.0
# Number of inter crosslinks: 17.0
# Number of target-target crosslinks: 111.0
# Number of target-decoy crosslinks: 0.0
# Number of decoy-decoy crosslinks: 0.0
# Minimum crosslink score: 49.37
# Maximum crosslink score: 231.06

# %% [markdown]
# # **Figures**

# %%
import os

if not os.path.exists("plots"):
    os.makedirs("plots")

# %%
import numpy as np

np.random.seed(1337)

# %% [markdown]
# **Calculate means and standard deviations for pLink**

# %%
plink_csms_mean = np.mean(
    [
        len(plink_r1["crosslink-spectrum-matches"]),
        len(plink_r2["crosslink-spectrum-matches"]),
        len(plink_r3["crosslink-spectrum-matches"]),
    ]
)
plink_csms_values = [
    len(plink_r1["crosslink-spectrum-matches"]),
    len(plink_r2["crosslink-spectrum-matches"]),
    len(plink_r3["crosslink-spectrum-matches"]),
]
plink_xls_mean = np.mean(
    [
        len(plink_r1["crosslinks"]),
        len(plink_r2["crosslinks"]),
        len(plink_r3["crosslinks"]),
    ]
)
plink_xls_values = [
    len(plink_r1["crosslinks"]),
    len(plink_r2["crosslinks"]),
    len(plink_r3["crosslinks"]),
]
print(plink_csms_mean)
print(plink_csms_values)
print(plink_xls_mean)
print(plink_xls_values)
# Out:
# 765.0
# [768, 765, 762]
# 428.3333333333333
# [443, 433, 409]

# %% [markdown]
# **Calculate means and standard deviations for Scout**

# %%
scout_csms_mean = np.mean(
    [
        len(scout_r1["crosslink-spectrum-matches"]),
        len(scout_r2["crosslink-spectrum-matches"]),
        len(scout_r3["crosslink-spectrum-matches"]),
    ]
)
scout_csms_values = [
    len(scout_r1["crosslink-spectrum-matches"]),
    len(scout_r2["crosslink-spectrum-matches"]),
    len(scout_r3["crosslink-spectrum-matches"]),
]
scout_xls_mean = np.mean(
    [
        len(scout_r1["crosslinks"]),
        len(scout_r2["crosslinks"]),
        len(scout_r3["crosslinks"]),
    ]
)
scout_xls_values = [
    len(scout_r1["crosslinks"]),
    len(scout_r2["crosslinks"]),
    len(scout_r3["crosslinks"]),
]
print(scout_csms_mean)
print(scout_csms_values)
print(scout_xls_mean)
print(scout_xls_values)
# Out:
# 285.3333333333333
# [271, 318, 267]
# 215.66666666666666
# [213, 234, 200]

# %% [markdown]
# **Calculate means and standard deviations for XlinkX**

# %%
xlinkx_csms_mean = np.mean(
    [
        len(xlinkx_r1["crosslink-spectrum-matches"]),
        len(xlinkx_r2["crosslink-spectrum-matches"]),
        len(xlinkx_r3["crosslink-spectrum-matches"]),
    ]
)
xlinkx_csms_values = [
    len(xlinkx_r1["crosslink-spectrum-matches"]),
    len(xlinkx_r2["crosslink-spectrum-matches"]),
    len(xlinkx_r3["crosslink-spectrum-matches"]),
]
xlinkx_xls_mean = np.mean(
    [
        len(xlinkx_r1["crosslinks"]),
        len(xlinkx_r2["crosslinks"]),
        len(xlinkx_r3["crosslinks"]),
    ]
)
xlinkx_xls_values = [
    len(xlinkx_r1["crosslinks"]),
    len(xlinkx_r2["crosslinks"]),
    len(xlinkx_r3["crosslinks"]),
]
print(xlinkx_csms_mean)
print(xlinkx_csms_values)
print(xlinkx_xls_mean)
print(xlinkx_xls_values)
# Out:
# 171.66666666666666
# [181, 205, 129]
# 146.0
# [157, 170, 111]

# %% [markdown]
# ## **Figure 2A**
#
# *****

# %%
import matplotlib.pyplot as plt

se = ("pLink", "Scout", "XlinkX")
se_means = {
    "CSMs": (plink_csms_mean, scout_csms_mean, xlinkx_csms_mean),
    "XLs": (plink_xls_mean, scout_xls_mean, xlinkx_xls_mean),
}
se_values = {
    "CSMs": (plink_csms_values, scout_csms_values, xlinkx_csms_values),
    "XLs": (plink_xls_values, scout_xls_values, xlinkx_xls_values),
}

x = np.arange(len(se))
width = 0.4
multiplier = 0
dev = 0.2
scatter = np.array([-dev * width, 0, dev * width])
pos = np.concat([scatter, scatter, scatter])

fig, ax = plt.subplots(layout="constrained", figsize=(7, 4))

colors = ["#6d4bff", "#ac99ff"]
for attribute, measurement in se_means.items():
    offset = width * multiplier
    rects = ax.bar(
        x + offset, measurement, width, label=attribute, color=colors[multiplier % 2]
    )
    p = ax.scatter(
        np.repeat(x + offset, len(se)) + pos, se_values[attribute], color="black"
    )
    ax.bar_label(rects, padding=14, fmt="{:.0f}")
    multiplier += 1

ax.set_xlabel("Crosslink Search Engine")
ax.set_ylabel("Average Number of CSMs and XLs (n=3)")
ax.set_title("Crosslink-Spectrum-Matches (CSMs) and Crosslinks (XLs) by Search Engine")
ax.set_xticks(x + width / 2, se)
ax.legend(loc="upper right", ncols=1)
ax.set_ylim(0, 860)

plt.savefig(
    "plots/figure2a.svg",
    dpi=300,
    transparent=True,
    bbox_inches="tight",
)

# %% [markdown]
# ## **Figure 2C**
#
# *****

# %%
pyXLMS.plotting.plot_venn_diagram(
    plink_r1["crosslinks"],
    plink_r2["crosslinks"],
    plink_r3["crosslinks"],
    by="protein",
    labels=["Replicate 1", "Replicate 2", "Replicate 3"],
    colors=["#6d4bff", "#ac99ff", "#ebe6ff"],
    title="Overlap of Replicates for XLs of pLink",
    alpha=1.0,
    figsize=(6, 6),
    filename_prefix="plots/pLink",
);

# %% [markdown]
# ## **Figure 2D**
#
# *****

# %%
pyXLMS.plotting.plot_venn_diagram(
    scout_r1["crosslinks"],
    scout_r2["crosslinks"],
    scout_r3["crosslinks"],
    by="protein",
    labels=["Replicate 1", "Replicate 2", "Replicate 3"],
    colors=["#6d4bff", "#ac99ff", "#ebe6ff"],
    title="Overlap of Replicates for XLs of Scout",
    alpha=1.0,
    figsize=(6, 6),
    filename_prefix="plots/Scout",
);

# %% [markdown]
# ## **Figure 2E**
#
# *****

# %%
pyXLMS.plotting.plot_venn_diagram(
    xlinkx_r1["crosslinks"],
    xlinkx_r2["crosslinks"],
    xlinkx_r3["crosslinks"],
    by="protein",
    labels=["Replicate 1", "Replicate 2", "Replicate 3"],
    colors=["#6d4bff", "#ac99ff", "#ebe6ff"],
    title="Overlap of Replicates for XLs of XlinkX",
    alpha=1.0,
    figsize=(6, 6),
    filename_prefix="plots/XlinkX",
);

# %% [markdown]
# ## **Figure 2B**
#
# *****

# %% [markdown]
# **Calculate intersection of XLs for pLink**

# %%
plink_intersection = pyXLMS.transform.intersection(
    pyXLMS.transform.intersection(
        plink_r1["crosslinks"], plink_r2["crosslinks"], by="protein", use="data_a"
    ),
    plink_r3["crosslinks"],
    by="protein",
    use="data_a",
)

# %% [markdown]
# **Calculate intersection of XLs for Scout**

# %%
scout_intersection = pyXLMS.transform.intersection(
    pyXLMS.transform.intersection(
        scout_r1["crosslinks"], scout_r2["crosslinks"], by="protein"
    ),
    scout_r3["crosslinks"],
    by="protein",
)

# %% [markdown]
# **Calculate intersection of XLs for XlinkX**

# %%
xlinkx_intersection = pyXLMS.transform.intersection(
    pyXLMS.transform.intersection(
        xlinkx_r1["crosslinks"], xlinkx_r2["crosslinks"], by="protein"
    ),
    xlinkx_r3["crosslinks"],
    by="protein",
)

# %%
pyXLMS.plotting.plot_venn_diagram(
    plink_intersection,
    scout_intersection,
    xlinkx_intersection,
    by="protein",
    labels=["pLink", "Scout", "XlinkX"],
    colors=["#6d4bff", "#ac99ff", "#ebe6ff"],
    title="Overlap of Intersections for XLs of all Search Engines",
    alpha=1.0,
    figsize=(6, 6),
    filename_prefix="plots/All",
);

# %% [markdown]
# # **Export**

# %%
if not os.path.exists("export"):
    os.makedirs("export")

# %% [markdown]
# ## **Export to xiVIEW**
#
# *****

# %%
pyXLMS.exporter.to_xiview(plink_intersection, filename="export/xiview_plink");

# %%
pyXLMS.exporter.to_xiview(scout_intersection, filename="export/xiview_scout");

# %%
pyXLMS.exporter.to_xiview(xlinkx_intersection, filename="export/xiview_xlinkx");

# %% [markdown]
# ## **Export to XMAS**
#
# *****

# %% [markdown]
# **Filter for CAS9 intra-crosslinks**

# %%
plink_intersection_cas9 = pyXLMS.transform.filter_proteins(
    plink_intersection, proteins=["CAS9HALO"]
)["Both"]
scout_intersection_cas9 = pyXLMS.transform.filter_proteins(
    scout_intersection, proteins=["CAS9HALO"]
)["Both"]
xlinkx_intersection_cas9 = pyXLMS.transform.filter_proteins(
    xlinkx_intersection, proteins=["CAS9HALO"]
)["Both"]

# %% [markdown]
# **Export to XMAS**

# %%
pyXLMS.exporter.to_xmas(plink_intersection_cas9, filename="export/xmas_plink");

# %%
pyXLMS.exporter.to_xmas(scout_intersection_cas9, filename="export/xmas_scout");

# %%
pyXLMS.exporter.to_xmas(xlinkx_intersection_cas9, filename="export/xmas_xlinkx");

# %% [markdown]
# ## **Export to XMAS & AlphaLink2**
#
# *****

# %% [markdown]
# **Create intersection of all CAS9 intra-crosslinks found in all three replicates of all search engine results**

# %%
all_intersection = pyXLMS.transform.intersection(
    pyXLMS.transform.intersection(
        plink_intersection_cas9, scout_intersection_cas9, by="protein", use="data_a"
    ),
    xlinkx_intersection_cas9,
    by="protein",
    use="data_a",
)

# %% [markdown]
# **Export to XMAS**

# %%
pyXLMS.exporter.to_xmas(all_intersection, filename="export/xmas_all");

# %% [markdown]
# **Export to AlphaLink2**

# %%
pyXLMS.exporter.to_alphalink2(
    all_intersection, fasta="fasta/cas9.fasta", filename_prefix="export/al2_all"
);
# Out:
# Exporting crosslinks to AlphaLink2...: 100%|██████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 27001.96it/s]
